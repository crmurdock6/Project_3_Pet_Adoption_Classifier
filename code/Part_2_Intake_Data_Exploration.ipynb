# %% [markdown]
# # Cleaning/Exploring Intake Data

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import re
import numpy as np
from collections import Counter
import data_cleaning as dc
from sqlalchemy import create_engine

# %% [markdown]
# ### Load dataframe

# %%
intakes_path = '/Users/murdock/Downloads/Austin_Animal_Center_Intakes.csv'

animal_intakes_df = pd.read_csv(intakes_path)

# %%
animal_intakes_df.head()
# Out:
#   Animal ID      Name                DateTime               MonthYear  \
# 0   A748291  *Madison  05/01/2017 02:26:00 PM  05/01/2017 02:26:00 PM
# 1   A730601       NaN  07/07/2016 12:11:00 PM  07/07/2016 12:11:00 PM
# 2   A748238       NaN  05/01/2017 10:53:00 AM  05/01/2017 10:53:00 AM
# 3   A683644     *Zoey  07/13/2014 11:02:00 AM  07/13/2014 11:02:00 AM
# 4   A748635       NaN  05/04/2017 05:56:00 PM  05/04/2017 05:56:00 PM
#
#                                       Found Location      Intake Type  \
# 0  S Pleasant Valley Rd And E Riverside Dr in Aus...            Stray
# 1                       1109 Shady Ln in Austin (TX)            Stray
# 2     Airport Blvd And Oak Springs Dr in Austin (TX)            Stray
# 3                                        Austin (TX)  Owner Surrender
# 4            11003 Harris Branch Pkwy in Austin (TX)            Stray
#
#   Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 0           Normal         Dog   Intact Female       10 months
# 1           Normal         Cat     Intact Male        7 months
# 2           Normal         Dog     Intact Male         3 years
# 3          Nursing         Dog   Intact Female         4 weeks
# 4           Normal         Cat         Unknown        9 months
#
#                     Breed        Color
# 0            Pit Bull Mix        Black
# 1  Domestic Shorthair Mix   Blue Tabby
# 2        Bichon Frise Mix        White
# 3       Border Collie Mix  Brown/White
# 4  Domestic Shorthair Mix         Blue

# %%
animal_intakes_df[animal_intakes_df['Animal ID'] == 'A677918']
# Out:
#       Animal ID   Name                DateTime               MonthYear  \
# 10583   A677918  Buddy  02/04/2015 10:45:00 AM  02/04/2015 10:45:00 AM
# 19845   A677918  Buddy  03/25/2015 06:41:00 PM  03/25/2015 06:41:00 PM
# 54043   A677918  Buddy  05/01/2014 10:58:00 AM  05/01/2014 10:58:00 AM
#
#                              Found Location      Intake Type Intake Condition  \
# 10583  Ih35 And Cesar Chavez in Austin (TX)            Stray           Normal
# 19845                           Austin (TX)  Owner Surrender           Normal
# 54043      1300 Southport Dr in Austin (TX)            Stray           Normal
#
#       Animal Type Sex upon Intake Age upon Intake         Breed  \
# 10583         Dog   Neutered Male         6 years  Pit Bull Mix
# 19845         Dog   Neutered Male         7 years  Pit Bull Mix
# 54043         Dog   Neutered Male         6 years  Pit Bull Mix
#
#                  Color
# 10583  White/Chocolate
# 19845  White/Chocolate
# 54043  White/Chocolate

# %%
animal_intakes_df = animal_intakes_df[animal_intakes_df['Animal Type'] == 'Dog']

# %%
animal_intakes_df = animal_intakes_df.reset_index(drop=True)

# %%
animal_intakes_df['DateTime'] = pd.to_datetime(animal_intakes_df['DateTime'], format='%m/%d/%Y %H:%M:%S %p')

# %%
animal_intakes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41357 entries, 0 to 41356
# Data columns (total 12 columns):
# Animal ID           41357 non-null object
# Name                34771 non-null object
# DateTime            41357 non-null datetime64[ns]
# MonthYear           41357 non-null object
# Found Location      41357 non-null object
# Intake Type         41357 non-null object
# Intake Condition    41357 non-null object
# Animal Type         41357 non-null object
# Sex upon Intake     41356 non-null object
# Age upon Intake     41357 non-null object
# Breed               41357 non-null object
# Color               41357 non-null object
# dtypes: datetime64[ns](1), object(11)
# memory usage: 3.8+ MB

# %%
animal_intakes_df.head(10)
# Out:
#   Animal ID       Name            DateTime               MonthYear  \
# 0   A748291   *Madison 2017-05-01 02:26:00  05/01/2017 02:26:00 PM
# 1   A748238        NaN 2017-05-01 10:53:00  05/01/2017 10:53:00 AM
# 2   A683644      *Zoey 2014-07-13 11:02:00  07/13/2014 11:02:00 AM
# 3   A676515       Rico 2014-04-11 08:45:00  04/11/2014 08:45:00 AM
# 4   A692161     George 2014-11-15 03:18:00  11/15/2014 03:18:00 PM
# 5   A720597  *Franklin 2016-02-12 02:35:00  02/12/2016 02:35:00 PM
# 6   A749535     *Bongo 2017-05-16 11:29:00  05/16/2017 11:29:00 AM
# 7   A711377       Ruso 2015-09-06 09:26:00  09/06/2015 09:26:00 AM
# 8   A715806  *Samantha 2015-11-10 12:49:00  11/10/2015 12:49:00 PM
# 9   A671448     Xander 2014-01-24 02:54:00  01/24/2014 02:54:00 PM
#
#                                       Found Location      Intake Type  \
# 0  S Pleasant Valley Rd And E Riverside Dr in Aus...            Stray
# 1     Airport Blvd And Oak Springs Dr in Austin (TX)            Stray
# 2                                        Austin (TX)  Owner Surrender
# 3                      615 E. Wonsley in Austin (TX)            Stray
# 4                       Avenue G/42Nd in Austin (TX)  Owner Surrender
# 5                    8413 Danville Dr in Austin (TX)            Stray
# 6            6607 S Ih 35 Frontage Rd in Austin (TX)            Stray
# 7            Los Arbolos Neighborhood in Austin (TX)            Stray
# 8               1506 Thorneridge Road in Austin (TX)            Stray
# 9                                        Austin (TX)    Public Assist
#
#   Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 0           Normal         Dog   Intact Female       10 months
# 1           Normal         Dog     Intact Male         3 years
# 2          Nursing         Dog   Intact Female         4 weeks
# 3           Normal         Dog     Intact Male        2 months
# 4           Normal         Dog     Intact Male        5 months
# 5          Injured         Dog     Intact Male         2 years
# 6           Normal         Dog     Intact Male         2 years
# 7           Normal         Dog     Intact Male        3 months
# 8           Normal         Dog   Intact Female         2 years
# 9           Normal         Dog   Neutered Male         3 years
#
#                       Breed        Color
# 0              Pit Bull Mix        Black
# 1          Bichon Frise Mix        White
# 2         Border Collie Mix  Brown/White
# 3              Pit Bull Mix  White/Brown
# 4              Pit Bull Mix  Brown/White
# 5              Pit Bull Mix         Blue
# 6         Border Collie Mix  Black/White
# 7       Anatol Shepherd Mix    Brown/Tan
# 8  Boxer/Labrador Retriever        Black
# 9             Pekingese Mix  Brown/White

# %% [markdown]
# ### Convert all ages to months

# %%
animal_intakes_df['Age upon Intake'] = animal_intakes_df['Age upon Intake'].apply(dc.convert_ages)

# %% [markdown]
# ### Select columns to keep

# %%
animal_intakes_df = animal_intakes_df[['Animal ID', 'DateTime', 'Intake Type', 'Intake Condition', 'Sex upon Intake', 'Age upon Intake']]

# %%
animal_intakes_df.columns = ['animalid', 'datetime', 'intaketype', 'intakecondition', 'sexuponintake', 'ageuponintake']
animal_intakes_df.head()
# Out:
#   animalid            datetime       intaketype intakecondition  \
# 0  A748291 2017-05-01 02:26:00            Stray          Normal
# 1  A748238 2017-05-01 10:53:00            Stray          Normal
# 2  A683644 2014-07-13 11:02:00  Owner Surrender         Nursing
# 3  A676515 2014-04-11 08:45:00            Stray          Normal
# 4  A692161 2014-11-15 03:18:00  Owner Surrender          Normal
#
#    sexuponintake  ageuponintake
# 0  Intact Female           10.0
# 1    Intact Male           36.0
# 2  Intact Female            1.0
# 3    Intact Male            2.0
# 4    Intact Male            5.0

# %% [markdown]
# ### Pickle Dataframe

# %%
path = '/Users/murdock/Documents/metis/project3/intake_data.pkl'
animal_intakes_df.to_pickle(path)

# %% [markdown]
# ### Upload to psql

# %%
engine_name = 'postgresql://credentials/project3'
cnx = create_engine(engine_name)

# %%
animal_intakes_df.to_sql("animal_intakes", cnx)

# %%
animal_intakes_df[animal_intakes_df['Animal ID'] == 'A552088']
# Out:
#       Animal ID   Name                DateTime               MonthYear  \
# 20562   A552088  Sasha  09/12/2014 06:51:00 PM  09/12/2014 06:51:00 PM
# 41650   A552088  Sasha  09/13/2015 01:20:00 PM  09/13/2015 01:20:00 PM
#
#                                    Found Location Intake Type  \
# 20562         Delano St And Hudson in Austin (TX)       Stray
# 41650  7825 Elkhorn Mountain Trail in Austin (TX)       Stray
#
#       Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 20562           Normal         Dog   Spayed Female         5 years
# 41650           Normal         Dog   Spayed Female         6 years
#
#                         Breed  Color
# 20562  Labrador Retriever Mix  Brown
# 41650  Labrador Retriever Mix  Brown
