# %% [markdown]
# # SQL Queries - Merging animal outcome data with animal intake data for three different types of breed combinations

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine

# %%
engine_name = 'postgresql://credentials/project3'
cnx = create_engine(engine_name)

# %%
pd.read_sql_query('''SELECT * FROM animal_outcomes LIMIT 5''',cnx)
# Out:
#    index animalid          name            datetime               monthyear  \
# 0      0  A658751         Benji 2016-11-13 01:38:00  11/13/2016 01:38:00 PM
# 1      1  A746650          Rose 2017-04-07 11:58:00  04/07/2017 11:58:00 AM
# 2      2  A750122  Happy Camper 2017-05-24 06:36:00  05/24/2017 06:36:00 PM
# 3      3  A666430          Lucy 2013-11-07 11:47:00  11/07/2013 11:47:00 AM
# 4      4  A675708       *Johnny 2014-06-03 02:20:00  06/03/2014 02:20:00 PM
#
#   dateofbirth      outcometype outcomesubtype animaltype sexuponoutcome  \
# 0  07/14/2011  Return to Owner           None        Dog  Neutered Male
# 1  04/06/2016  Return to Owner           None        Dog  Intact Female
# 2  04/08/2017         Transfer        Partner        Dog    Intact Male
# 3  11/06/2012         Transfer        Partner        Dog  Spayed Female
# 4  03/31/2013         Adoption           None        Dog  Neutered Male
#
#    ageuponoutcome                                    breed     color
# 0            60.0                       Border Terrier Mix       Tan
# 1            12.0  Jack Russell Terrier/Labrador Retriever    Yellow
# 2             1.0                   Labrador Retriever Mix     Black
# 3            12.0                               Beagle Mix  Twocolor
# 4            12.0                                 Pit Bull  Twocolor

# %%
outcomes = pd.read_sql_query('''SELECT * FROM animal_outcomes''',cnx)

# %%
outcomes.head()
# Out:
#    index animalid          name            datetime               monthyear  \
# 0      0  A658751         Benji 2016-11-13 01:38:00  11/13/2016 01:38:00 PM
# 1      1  A746650          Rose 2017-04-07 11:58:00  04/07/2017 11:58:00 AM
# 2      2  A750122  Happy Camper 2017-05-24 06:36:00  05/24/2017 06:36:00 PM
# 3      3  A666430          Lucy 2013-11-07 11:47:00  11/07/2013 11:47:00 AM
# 4      4  A675708       *Johnny 2014-06-03 02:20:00  06/03/2014 02:20:00 PM
#
#   dateofbirth      outcometype outcomesubtype animaltype sexuponoutcome  \
# 0  07/14/2011  Return to Owner           None        Dog  Neutered Male
# 1  04/06/2016  Return to Owner           None        Dog  Intact Female
# 2  04/08/2017         Transfer        Partner        Dog    Intact Male
# 3  11/06/2012         Transfer        Partner        Dog  Spayed Female
# 4  03/31/2013         Adoption           None        Dog  Neutered Male
#
#    ageuponoutcome                                    breed     color
# 0            60.0                       Border Terrier Mix       Tan
# 1            12.0  Jack Russell Terrier/Labrador Retriever    Yellow
# 2             1.0                   Labrador Retriever Mix     Black
# 3            12.0                               Beagle Mix  Twocolor
# 4            12.0                                 Pit Bull  Twocolor

# %%
outcomes['outcometype'].unique()
# Out:
# array(['Return to Owner', 'Transfer', 'Adoption', 'Euthanasia', 'Disposal',
#        'Rto-Adopt', 'Died', 'Missing'], dtype=object)

# %% [markdown]
# ### Obtain workflow for merging tables. Practice with the unaltered animal intake and outcome tables

# %%
merge_tables = pd.read_sql_query('''SELECT *
                                    FROM (SELECT
                                    animal_outcomes.datetime - animal_intakes.datetime AS "TIME_DIFF",
                                    animal_outcomes.animalid as "ID",
                                    animal_outcomes.name as "NAME",
                                    animal_outcomes.datetime as "OUTCOME_TIME",
                                    animal_outcomes.outcometype as "OUTCOME_TYPE",
                                    animal_outcomes.outcomesubtype as "OUTCOME_SUBTYPE",
                                    animal_outcomes.sexuponoutcome as "SEX_ON_OUTCOME",
                                    animal_outcomes.ageuponoutcome "AGE_ON_OUTCOME",
                                    animal_outcomes.breed as "BREED",
                                    animal_outcomes.color as "COLOR",
                                    animal_intakes.datetime as "INTAKE_TIME",
                                    animal_intakes.intaketype as "INTAKE_TYPE",
                                    animal_intakes.intakecondition as "INTAKE_CONDITION",
                                    animal_intakes.sexuponintake as "SEX_ON_INTAKE",
                                    animal_intakes.ageuponintake as "AGE_ON_INTAKE",
                                    row_number() over(PARTITION BY animal_outcomes.animalid
                                    ORDER BY abs(extract(epoch from (animal_outcomes.datetime - animal_intakes.datetime)))) AS rn
                                    FROM
                                        animal_outcomes
                                    JOIN
                                        animal_intakes
                                    ON 
                                        animal_outcomes.animalid = animal_intakes.animalid 
                                    WHERE animal_outcomes.datetime > animal_intakes.datetime) AS derivedtable
                                    WHERE rn=1''',cnx)

# %%
merge_tables.head()
# Out:
#         TIME_DIFF       ID    NAME        OUTCOME_TIME     OUTCOME_TYPE  \
# 0 0 days 18:14:00  A006100   Scamp 2014-12-20 04:35:00  Return to Owner
# 1 4 days 23:17:00  A047759    Oreo 2014-04-07 03:12:00         Transfer
# 2 0 days 02:52:00  A134067  Bandit 2013-11-16 11:54:00  Return to Owner
# 3 1 days 08:54:00  A141142  Bettie 2013-11-17 11:40:00  Return to Owner
# 4 0 days 04:17:00  A163459   Sasha 2014-11-14 07:28:00  Return to Owner
#
#   OUTCOME_SUBTYPE SEX_ON_OUTCOME  AGE_ON_OUTCOME                        BREED  \
# 0            None  Neutered Male            84.0         Spinone Italiano Mix
# 1         Partner  Neutered Male           120.0                    Dachshund
# 2            None  Neutered Male           192.0            Shetland Sheepdog
# 3            None  Spayed Female           180.0  Labrador Retriever/Pit Bull
# 4            None  Intact Female           180.0      Miniature Schnauzer Mix
#
#       COLOR         INTAKE_TIME      INTAKE_TYPE INTAKE_CONDITION  \
# 0  Twocolor 2014-12-19 10:21:00    Public Assist           Normal
# 1  Tricolor 2014-04-02 03:55:00  Owner Surrender           Normal
# 2  Twocolor 2013-11-16 09:02:00    Public Assist          Injured
# 3  Twocolor 2013-11-16 02:46:00            Stray             Aged
# 4  Twocolor 2014-11-14 03:11:00            Stray           Normal
#
#    SEX_ON_INTAKE  AGE_ON_INTAKE  rn
# 0  Neutered Male           84.0   1
# 1  Neutered Male          120.0   1
# 2  Neutered Male          192.0   1
# 3  Spayed Female          180.0   1
# 4  Intact Female          180.0   1

# %%
merge_tables[merge_tables['ID'] == 'A552088']
# Out:
#             TIME_DIFF       ID   NAME        OUTCOME_TIME OUTCOME_TYPE  \
# 608 202 days 23:37:00  A552088  Sasha 2015-04-03 06:28:00     Adoption
#
#     OUTCOME_SUBTYPE SEX_ON_OUTCOME  AGE_ON_OUTCOME                   BREED  \
# 608            None  Spayed Female            72.0  Labrador Retriever Mix
#
#      COLOR         INTAKE_TIME INTAKE_TYPE INTAKE_CONDITION  SEX_ON_INTAKE  \
# 608  Brown 2014-09-12 06:51:00       Stray           Normal  Spayed Female
#
#      AGE_ON_INTAKE  rn
# 608           60.0   1

# %%
merge_tables[merge_tables['ID'] == 'A720298']
# Out:
#             TIME_DIFF       ID   NAME        OUTCOME_TIME     OUTCOME_TYPE  \
# 21772 4 days 04:04:00  A720298  Bully 2016-02-10 05:28:00  Return to Owner
#
#       OUTCOME_SUBTYPE SEX_ON_OUTCOME  AGE_ON_OUTCOME         BREED     COLOR  \
# 21772            None  Neutered Male             3.0  Pit Bull Mix  Twocolor
#
#               INTAKE_TIME INTAKE_TYPE INTAKE_CONDITION SEX_ON_INTAKE  \
# 21772 2016-02-06 01:24:00       Stray           Normal   Intact Male
#
#        AGE_ON_INTAKE  rn
# 21772            3.0   1

# %%
len(merge_tables['ID'].unique())
# Out:
# 34043

# %% [markdown]
# ### Pickle dataframe

# %%
path1 = '/Users/murdock/Documents/metis/project3/merged_animals.pkl'
merge_tables.to_pickle(path1)

# %% [markdown]
# ### Merge Purebred vs. Not Purebred Dataframes

# %%
purevsmix_tables = pd.read_sql_query('''SELECT *
                                        FROM (SELECT
                                        purevsmix_outcomes.datetime - animal_intakes.datetime AS "TIME_DIFF",
                                        purevsmix_outcomes.animalid as "ID",
                                        purevsmix_outcomes.name as "NAME",
                                        purevsmix_outcomes.datetime as "OUTCOME_TIME",
                                        purevsmix_outcomes.outcometype as "OUTCOME_TYPE",
                                        purevsmix_outcomes.outcomesubtype as "OUTCOME_SUBTYPE",
                                        purevsmix_outcomes.sexuponoutcome as "SEX_ON_OUTCOME",
                                        purevsmix_outcomes.ageuponoutcome "AGE_ON_OUTCOME",
                                        purevsmix_outcomes.breed as "BREED",
                                        purevsmix_outcomes.color as "COLOR",
                                        animal_intakes.datetime as "INTAKE_TIME",
                                        animal_intakes.intaketype as "INTAKE_TYPE",
                                        animal_intakes.intakecondition as "INTAKE_CONDITION",
                                        animal_intakes.sexuponintake as "SEX_ON_INTAKE",
                                        animal_intakes.ageuponintake as "AGE_ON_INTAKE",
                                        row_number() over(PARTITION BY purevsmix_outcomes.animalid
                                        ORDER BY abs(extract(epoch from (purevsmix_outcomes.datetime - animal_intakes.datetime)))) AS rn
                                        FROM
                                            purevsmix_outcomes
                                        JOIN
                                            animal_intakes
                                        ON 
                                            purevsmix_outcomes.animalid = animal_intakes.animalid
                                        WHERE purevsmix_outcomes.datetime > animal_intakes.datetime) AS derivedtable
                                        WHERE rn=1''',cnx)

# %%
purevsmix_tables.sample(10)
# Out:
#              TIME_DIFF       ID     NAME        OUTCOME_TIME     OUTCOME_TYPE  \
# 7815   0 days 00:41:00  A679029     None 2014-05-15 03:54:00       Euthanasia
# 8757  51 days 18:57:00  A681970   *Allie 2014-08-13 05:44:00         Adoption
# 17595 10 days 18:15:00  A707494  Karamel 2015-07-24 04:06:00  Return to Owner
# 14229 13 days 06:31:00  A697261   Roltan 2015-10-24 12:00:00         Adoption
# 21459 88 days 09:23:00  A719504   *Eagle 2016-04-18 12:00:00         Transfer
# 11986  0 days 14:46:00  A691817   Deacon 2014-11-11 01:58:00  Return to Owner
# 32814  1 days 19:33:00  A755608     None 2017-08-08 04:49:00         Transfer
# 5651   4 days 02:12:00  A672558   *Frida 2014-02-16 06:08:00         Adoption
# 32881  4 days 16:25:00  A755873     None 2017-08-15 03:24:00         Adoption
# 12640  7 days 03:57:00  A693552   Cooper 2014-12-17 05:31:00         Transfer
#
#       OUTCOME_SUBTYPE SEX_ON_OUTCOME  AGE_ON_OUTCOME        BREED      COLOR  \
# 7815        Suffering    Intact Male            10.0  Mixed Breed   Twocolor
# 8757           Foster  Spayed Female             1.0  Mixed Breed       Tick
# 17595            None  Intact Female           108.0  Mixed Breed   Twocolor
# 14229            None  Neutered Male            11.0  Mixed Breed   Twocolor
# 21459         Partner  Neutered Male            36.0  Mixed Breed   Twocolor
# 11986            None  Neutered Male            48.0  Mixed Breed   Twocolor
# 32814         Partner  Intact Female             1.0  Mixed Breed  Chocolate
# 5651             None  Spayed Female            12.0  Mixed Breed   Twocolor
# 32881            None  Neutered Male             3.0     Purebred        Red
# 12640         Partner    Intact Male             4.0  Mixed Breed   Twocolor
#
#               INTAKE_TIME    INTAKE_TYPE INTAKE_CONDITION  SEX_ON_INTAKE  \
# 7815  2014-05-15 03:13:00          Stray             Sick    Intact Male
# 8757  2014-06-22 10:47:00          Stray           Normal  Intact Female
# 17595 2015-07-13 09:51:00  Public Assist           Normal  Intact Female
# 14229 2015-10-11 05:29:00          Stray           Normal  Neutered Male
# 21459 2016-01-21 02:37:00          Stray           Normal    Intact Male
# 11986 2014-11-10 11:12:00  Public Assist           Normal  Neutered Male
# 32814 2017-08-06 09:16:00          Stray           Normal  Intact Female
# 5651  2014-02-12 03:56:00          Stray           Normal  Intact Female
# 32881 2017-08-10 10:59:00          Stray           Normal    Intact Male
# 12640 2014-12-10 01:34:00          Stray           Normal    Intact Male
#
#        AGE_ON_INTAKE  rn
# 7815       10.000000   1
# 8757        0.133333   1
# 17595     108.000000   1
# 14229      10.000000   1
# 21459      36.000000   1
# 11986      48.000000   1
# 32814       1.000000   1
# 5651       12.000000   1
# 32881       3.000000   1
# 12640       4.000000   1

# %% [markdown]
# ### Pickle Dataframe

# %%
path2 = '/Users/murdock/Documents/metis/project3/purevsmix_mergedtables.pkl'
purevsmix_tables.to_pickle(path2)

# %% [markdown]
# ### Merge pitbull vs not pitbull tables

# %%
pitbullvsnot_tables = pd.read_sql_query('''SELECT *
                                           FROM (SELECT
                                           pitbull_outcomes.datetime - animal_intakes.datetime AS "TIME_DIFF",
                                           pitbull_outcomes.animalid as "ID",
                                           pitbull_outcomes.name as "NAME",
                                           pitbull_outcomes.datetime as "OUTCOME_TIME",
                                           pitbull_outcomes.outcometype as "OUTCOME_TYPE",
                                           pitbull_outcomes.outcomesubtype as "OUTCOME_SUBTYPE",
                                           pitbull_outcomes.sexuponoutcome as "SEX_ON_OUTCOME",
                                           pitbull_outcomes.ageuponoutcome "AGE_ON_OUTCOME",
                                           pitbull_outcomes.breed as "BREED",
                                           pitbull_outcomes.color as "COLOR",
                                           animal_intakes.datetime as "INTAKE_TIME",
                                           animal_intakes.intaketype as "INTAKE_TYPE",
                                           animal_intakes.intakecondition as "INTAKE_CONDITION",
                                           animal_intakes.sexuponintake as "SEX_ON_INTAKE",
                                           animal_intakes.ageuponintake as "AGE_ON_INTAKE",
                                           row_number() over(PARTITION BY pitbull_outcomes.animalid
                                           ORDER BY abs(extract(epoch from (pitbull_outcomes.datetime - animal_intakes.datetime)))) AS rn
                                           FROM
                                               pitbull_outcomes
                                           JOIN
                                               animal_intakes
                                           ON 
                                               pitbull_outcomes.animalid = animal_intakes.animalid
                                           WHERE pitbull_outcomes.datetime > animal_intakes.datetime) AS derivedtable
                                           WHERE rn=1''',cnx)

# %%
pitbullvsnot_tables.head()
# Out:
#         TIME_DIFF       ID    NAME        OUTCOME_TIME     OUTCOME_TYPE  \
# 0 0 days 18:14:00  A006100   Scamp 2014-12-20 04:35:00  Return to Owner
# 1 4 days 23:17:00  A047759    Oreo 2014-04-07 03:12:00         Transfer
# 2 0 days 02:52:00  A134067  Bandit 2013-11-16 11:54:00  Return to Owner
# 3 1 days 08:54:00  A141142  Bettie 2013-11-17 11:40:00  Return to Owner
# 4 0 days 04:17:00  A163459   Sasha 2014-11-14 07:28:00  Return to Owner
#
#   OUTCOME_SUBTYPE SEX_ON_OUTCOME  AGE_ON_OUTCOME         BREED     COLOR  \
# 0            None  Neutered Male            84.0  Not Pit Bull  Twocolor
# 1         Partner  Neutered Male           120.0  Not Pit Bull  Tricolor
# 2            None  Neutered Male           192.0  Not Pit Bull  Twocolor
# 3            None  Spayed Female           180.0      Pit Bull  Twocolor
# 4            None  Intact Female           180.0  Not Pit Bull  Twocolor
#
#           INTAKE_TIME      INTAKE_TYPE INTAKE_CONDITION  SEX_ON_INTAKE  \
# 0 2014-12-19 10:21:00    Public Assist           Normal  Neutered Male
# 1 2014-04-02 03:55:00  Owner Surrender           Normal  Neutered Male
# 2 2013-11-16 09:02:00    Public Assist          Injured  Neutered Male
# 3 2013-11-16 02:46:00            Stray             Aged  Spayed Female
# 4 2014-11-14 03:11:00            Stray           Normal  Intact Female
#
#    AGE_ON_INTAKE  rn
# 0           84.0   1
# 1          120.0   1
# 2          192.0   1
# 3          180.0   1
# 4          180.0   1

# %% [markdown]
# ### Pickle Dataframe

# %%
path3 = '/Users/murdock/Documents/metis/project3/pitbull_mergedtables.pkl'
pitbullvsnot_tables.to_pickle(path3)

# %% [markdown]
# ### Merge breeds with low occurrences (< 50)

# %%
lowoccur_tables = pd.read_sql_query('''SELECT *
                                       FROM (SELECT
                                       lowoccur_outcomes.datetime - animal_intakes.datetime AS "TIME_DIFF",
                                       lowoccur_outcomes.animalid as "ID",
                                       lowoccur_outcomes.name as "NAME",
                                       lowoccur_outcomes.datetime as "OUTCOME_TIME",
                                       lowoccur_outcomes.outcometype as "OUTCOME_TYPE",
                                       lowoccur_outcomes.outcomesubtype as "OUTCOME_SUBTYPE",
                                       lowoccur_outcomes.sexuponoutcome as "SEX_ON_OUTCOME",
                                       lowoccur_outcomes.ageuponoutcome "AGE_ON_OUTCOME",
                                       lowoccur_outcomes.breed as "BREED",
                                       lowoccur_outcomes.color as "COLOR",
                                       animal_intakes.datetime as "INTAKE_TIME",
                                       animal_intakes.intaketype as "INTAKE_TYPE",
                                       animal_intakes.intakecondition as "INTAKE_CONDITION",
                                       animal_intakes.sexuponintake as "SEX_ON_INTAKE",
                                       animal_intakes.ageuponintake as "AGE_ON_INTAKE",
                                       row_number() over(PARTITION BY lowoccur_outcomes.animalid
                                       ORDER BY abs(extract(epoch from (lowoccur_outcomes.datetime - animal_intakes.datetime)))) AS rn
                                       FROM
                                           lowoccur_outcomes
                                       JOIN
                                           animal_intakes
                                       ON 
                                           lowoccur_outcomes.animalid = animal_intakes.animalid
                                       WHERE lowoccur_outcomes.datetime > animal_intakes.datetime) AS derivedtable
                                       WHERE rn=1''',cnx)

# %%
lowoccur_tables.head()
# Out:
#         TIME_DIFF       ID    NAME        OUTCOME_TIME     OUTCOME_TYPE  \
# 0 0 days 18:14:00  A006100   Scamp 2014-12-20 04:35:00  Return to Owner
# 1 4 days 23:17:00  A047759    Oreo 2014-04-07 03:12:00         Transfer
# 2 0 days 02:52:00  A134067  Bandit 2013-11-16 11:54:00  Return to Owner
# 3 1 days 08:54:00  A141142  Bettie 2013-11-17 11:40:00  Return to Owner
# 4 0 days 04:17:00  A163459   Sasha 2014-11-14 07:28:00  Return to Owner
#
#   OUTCOME_SUBTYPE SEX_ON_OUTCOME  AGE_ON_OUTCOME                        BREED  \
# 0            None  Neutered Male            84.0            Other Mixed Breed
# 1         Partner  Neutered Male           120.0                    Dachshund
# 2            None  Neutered Male           192.0               Other Purebred
# 3            None  Spayed Female           180.0  Labrador Retriever/Pit Bull
# 4            None  Intact Female           180.0      Miniature Schnauzer Mix
#
#       COLOR         INTAKE_TIME      INTAKE_TYPE INTAKE_CONDITION  \
# 0  Twocolor 2014-12-19 10:21:00    Public Assist           Normal
# 1  Tricolor 2014-04-02 03:55:00  Owner Surrender           Normal
# 2  Twocolor 2013-11-16 09:02:00    Public Assist          Injured
# 3  Twocolor 2013-11-16 02:46:00            Stray             Aged
# 4  Twocolor 2014-11-14 03:11:00            Stray           Normal
#
#    SEX_ON_INTAKE  AGE_ON_INTAKE  rn
# 0  Neutered Male           84.0   1
# 1  Neutered Male          120.0   1
# 2  Neutered Male          192.0   1
# 3  Spayed Female          180.0   1
# 4  Intact Female          180.0   1

# %% [markdown]
# ### Pickle Dataframe

# %%
path4 = '/Users/murdock/Documents/metis/project3/lowoccur_mergedtables.pkl'
lowoccur_tables.to_pickle(path4)
